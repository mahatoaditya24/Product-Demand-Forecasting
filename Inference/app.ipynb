# %%
import streamlit as st
from Predict_freight import predict_freight_cost
from predict_invoice_flag import predict_invoice_flag

# -------------------------------
# Page Configuration
# -------------------------------
st.set_page_config(
    page_title="Vendor Invoice Intelligence Portal",
    page_icon="📦",
    layout="wide"
)

# -------------------------------
# Header
# -------------------------------
st.title("📦 Vendor Invoice Intelligence Portal")
st.subheader("AI-Driven Freight Cost Prediction & Invoice Risk Flagging")

st.markdown("""
This internal analytics portal leverages machine learning to:

- 🚛 Forecast freight costs accurately
- 🚨 Detect risky vendor invoices
- 💰 Reduce financial leakage
- ⚡ Improve finance operations
""")

st.divider()

# -------------------------------
# Sidebar
# -------------------------------
st.sidebar.title("🔍 Model Selection")

selected_model = st.sidebar.radio(
    "Choose Prediction Module",
    (
        "Freight Cost Prediction",
        "Invoice Manual Approval Flag"
    )
)

st.sidebar.markdown("---")
st.sidebar.markdown("""
### Business Impact
- 📈 Better Cost Forecasting
- 🧾 Fraud Detection
- ⚙️ Faster Finance Operations
""")

# ===========================================================
# Freight Prediction
# ===========================================================
if selected_model == "Freight Cost Prediction":

    st.header("🚛 Freight Cost Prediction")

    with st.form("freight_form"):

        col1, col2 = st.columns(2)

        with col1:
            quantity = st.number_input(
                "Quantity",
                min_value=1,
                value=1200
            )

        with col2:
            dollars = st.number_input(
                "Invoice Dollars",
                min_value=1.0,
                value=18500.0
            )

        submit = st.form_submit_button("Predict Freight Cost")

    if submit:

        input_data = {
            "Quantity": [quantity],
            "Dollars": [dollars]
        }

        result = predict_freight_cost(input_data)

        freight = result["Predict_Freight"][0]

        st.success("Prediction Successful!")

        st.metric(
            "Estimated Freight Cost",
            f"${freight:,.2f}"
        )

# ===========================================================
# Invoice Flag Prediction
# ===========================================================
else:

    st.header("🚨 Invoice Manual Approval Prediction")

    with st.form("invoice_form"):

        col1, col2, col3 = st.columns(3)

        with col1:

            invoice_quantity = st.number_input(
                "Invoice Quantity",
                min_value=1,
                value=50
            )

            freight = st.number_input(
                "Freight",
                min_value=0.0,
                value=1.73
            )

        with col2:

            invoice_dollars = st.number_input(
                "Invoice Dollars",
                min_value=1.0,
                value=352.95
            )

            total_item_quantity = st.number_input(
                "Total Item Quantity",
                min_value=1,
                value=162
            )

        with col3:

            total_item_dollars = st.number_input(
                "Total Item Dollars",
                min_value=1.0,
                value=2476.0
            )

        submit = st.form_submit_button("Evaluate Invoice")

    if submit:

        input_data = {
            "invoice_quantity": [invoice_quantity],
            "invoice_dollars": [invoice_dollars],
            "Freight": [freight],
            "total_item_quantity": [total_item_quantity],
            "total_item_dollars": [total_item_dollars]
        }

        result = predict_invoice_flag(input_data)

        flag = int(result["Predict_Flag"][0])

        if flag == 1:
            st.error("🚨 Invoice requires Manual Approval")
        else:
            st.success("✅ Invoice Approved Automatically")

        st.subheader("Prediction Details")
        st.dataframe(result, use_container_width=True)
# Out:
# 2026-08-06 10:47:25.973 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:25.974 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.512
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run D:\DS\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-08-06 10:47:26.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.532 Session state does not function when running a script without `streamlit run`
# 2026-08-06 10:47:26.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 10:47:26.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import os

for root, dirs, files in os.walk("."):
    print(root)
    for f in files:
        print("   ", f)
# Out:
# .
#     app.ipynb
#     best_demand_forecasting_model.pkl
# .\.ipynb_checkpoints
#     app-checkpoint.ipynb
# .\data
#     inventory.db
#     Product_Demand_main.csv
# .\data\.ipynb_checkpoints
#     Product_Demand_main-checkpoint.csv
# .\Freight Cost Prediction
#     data_preprocessing.ipynb
#     model_evaluation.ipynb
#     model_evaluation.py
#     train.py.ipynb
# .\Freight Cost Prediction\.ipynb_checkpoints
#     data_preprocessing-checkpoint.ipynb
#     model_evaluation-checkpoint.ipynb
#     model_evaluation-checkpoint.py
#     train.py-checkpoint.ipynb
# .\Freight Cost Prediction\models
#     data_preprocessing.ipynb
#     data_preprocessing.py
#     model_evaluation.ipynb
#     model_evaluation.py
#     predict_freight_model.pkl
#     train.py.ipynb
# .\Freight Cost Prediction\models\.ipynb_checkpoints
#     data_preprocessing-checkpoint.ipynb
#     data_preprocessing-checkpoint.py
#     model_evaluation-checkpoint.ipynb
#     model_evaluation-checkpoint.py
#     train.py-checkpoint.ipynb
# .\Freight Cost Prediction\models\__pycache__
#     data_preprocessing.cpython-312.pyc
# .\Freight Cost Prediction\__pycache__
#     data_preprocessing.cpython-312.pyc
#     model_evaluation.cpython-312.pyc
# .\Inference
#     predict_flag_invoice.pkl
#     Predict_freight.ipynb
#     Predict_freight.py
#     predict_freight_model.pkl
#     predict_invoice_flag.ipynb
#     predict_invoice_flag.py
#     scaler.pkl
#     __init__.py
# .\Inference\.ipynb_checkpoints
#     Predict_freight-checkpoint.ipynb
#     Predict_freight-checkpoint.py
#     predict_invoice_flag-checkpoint.ipynb
#     predict_invoice_flag-checkpoint.py
# .\invoice_flagging
#     data_preprocessing.ipynb
#     modeling_evaluation.ipynb
# .\invoice_flagging\.ipynb_checkpoints
#     data_preprocessing-checkpoint.ipynb
#     modeling_evaluation-checkpoint.ipynb
# .\invoice_flagging\models
#     data_preprocessing.ipynb
#     data_preprocessing.py
#     modeling_evaluation.ipynb
#     modeling_evaluation.py
#     train.ipynb
# .\invoice_flagging\models\.ipynb_checkpoints
#     data_preprocessing-checkpoint.ipynb
#     data_preprocessing-checkpoint.py
#     modeling_evaluation-checkpoint.ipynb
#     modeling_evaluation-checkpoint.py
#     train-checkpoint.ipynb
# .\invoice_flagging\models\models
#     predict_flag_invoice.pkl
#     scaler.pkl
#     train.ipynb
# .\invoice_flagging\models\models\.ipynb_checkpoints
#     train-checkpoint.ipynb
# .\invoice_flagging\models\__pycache__
#     data_preprocessing.cpython-312.pyc
#     modeling_evaluation.cpython-312.pyc
# .\invoice_flagging\__pycache__
#     modeling_evaluation.cpython-312.pyc
# .\notebooks
#     Demand_forecast.ipynb
#     Invoice Flagging .ipynb
#     Predicting Freight Cost.ipynb
# .\notebooks\.ipynb_checkpoints
#     Demand_forecast-checkpoint.ipynb
#     Invoice Flagging -checkpoint.ipynb
#     Predicting Freight Cost-checkpoint.ipynb

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\ADITYA\Flipkart\Inference
# ['.ipynb_checkpoints', 'app.ipynb', 'app.py', 'predict_flag_invoice.pkl', 'Predict_freight.ipynb', 'Predict_freight.py', 'predict_freight_model.pkl', 'predict_invoice_flag.ipynb', 'predict_invoice_flag.py', 'scaler.pkl', '__init__.py', '__pycache__']
